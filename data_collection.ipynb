# %% [markdown]
# Install `google-play-scraper` package using: `pip install google-play-scraper`
#
#
# Please refer to https://pypi.org/project/google-play-scraper/ for details.

# %%
from google_play_scraper import Sort, reviews,reviews_all
import pandas as pd

# %%
# initialization

app_name = 'com.netflix.mediaclient' # found in app's url

rvws, token = reviews(
    app_name,           # found in app's url
    lang='en',        # defaults to 'en'
    country='us',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=200       # batch size, set as 200 since 200 reviews per page
)

app_reviews = rvws
batch_num=1

# %%
# Loop through the number of batches
for batch in range(1, 1000): # You can adjust the number of batches to collect more or less reviews
    rvws, token = reviews( # store continuation_token
        app_name,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        # using token obtained from previous batch
        continuation_token=token
    )
    app_reviews.extend(rvws)
    batch_num +=1

# %%
df = pd.DataFrame.from_records(app_reviews)
df
# Out:
#                                     reviewId         userName  \
# 0       1255bae6-a139-4b71-a750-193ddf177f10       Jacob Eddy
# 1       0e76ddd6-2839-4a73-a436-6e3138da1c58     Mehedi Hasan
# 2       7fead878-dd7e-42cb-8e85-c0d0cb100e71   Jennifer Ibama
# 3       6b47ec27-09c2-4dca-bcb7-1965de35c814     Zameer Abbas
# 4       6f8c5b47-8faf-472a-90d2-2ced3ba1e22d  Eiann Gracee Go
# ...                                      ...              ...
# 199995  56cf016f-f605-4e97-a5b1-33a58b17e626      Jasmin Bebe
# 199996  48a722dd-3228-4a5b-aaeb-0e51d9fe77dd        Dyan Mags
# 199997  84809923-5b66-4afa-8efa-b79f342d3de3     Charles Rose
# 199998  8ac9b780-d6c7-44ca-b2d1-a9d5c47db2ee  Rosemary Wangui
# 199999  f1da1921-2045-47f3-9d49-705f9ca6cff2           Josh O
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/ACg8oc...
# 1       https://play-lh.googleusercontent.com/a/ACg8oc...
# 2       https://play-lh.googleusercontent.com/a-/ALV-U...
# 3       https://play-lh.googleusercontent.com/a-/ALV-U...
# 4       https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                   ...
# 199995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 199996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 199997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 199998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 199999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                   content  score  \
# 0       Suddenly saying my device is not part of the f...      1
# 1       With Right Password.. I Can't Login My Account...      1
# 2                                          network issues      5
# 3                                                    Nice      5
# 4       I really like this movie I can watch anything ...      5
# ...                                                   ...    ...
# 199995                                               Nice      5
# 199996                       Good👍 but sometimes loading!      5
# 199997  Absolutely love Netflix. In fact we only have ...      5
# 199998                                  It has nice moves      5
# 199999  Needs more Horror movies, IT part 2 wood be nice.      4
#
#         thumbsUpCount    reviewCreatedVersion                  at  \
# 0                   0  8.142.1 build 13 51334 2025-01-20 13:46:43
# 1                   0   8.131.0 build 3 50829 2025-01-20 13:45:41
# 2                   0  8.142.1 build 13 51334 2025-01-20 13:37:47
# 3                   0  8.141.1 build 13 51230 2025-01-20 13:31:37
# 4                   0  8.142.1 build 13 51334 2025-01-20 13:22:11
# ...               ...                     ...                 ...
# 199995              0    8.34.0 build 4 50250 2022-08-15 17:46:44
# 199996              0    8.30.0 build 5 40236 2022-08-15 17:41:48
# 199997              0    8.30.0 build 5 40236 2022-08-15 17:41:31
# 199998              0                    None 2022-08-15 17:41:26
# 199999              0    8.34.0 build 4 50250 2022-08-15 17:40:18
#
#        replyContent repliedAt              appVersion
# 0              None      None  8.142.1 build 13 51334
# 1              None      None   8.131.0 build 3 50829
# 2              None      None  8.142.1 build 13 51334
# 3              None      None  8.141.1 build 13 51230
# 4              None      None  8.142.1 build 13 51334
# ...             ...       ...                     ...
# 199995         None      None    8.34.0 build 4 50250
# 199996         None      None    8.30.0 build 5 40236
# 199997         None      None    8.30.0 build 5 40236
# 199998         None      None                    None
# 199999         None      None    8.34.0 build 4 50250
#
# [200000 rows x 11 columns]

# %%
df.to_csv('netflix_reviews200k.csv',index=False)

# %%
df.score.value_counts()
# Out:
# score
# 1    82625
# 5    82112
# 4    14511
# 3    10583
# 2    10169
# Name: count, dtype: int64
